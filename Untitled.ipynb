# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.drop(["ocean_proximity"],axis=1 , inplace= True)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
# [20433 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
X = data.drop(['median_house_value'], axis =1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income
# 0           322.0       126.0         8.3252
# 1          2401.0      1138.0         8.3014
# 2           496.0       177.0         7.2574
# 3           558.0       219.0         5.6431
# 4           565.0       259.0         3.8462
# ...           ...         ...            ...
# 20635       845.0       330.0         1.5603
# 20636       356.0       114.0         2.5568
# 20637      1007.0       433.0         1.7000
# 20638       741.0       349.0         1.8672
# 20639      1387.0       530.0         2.3886
#
# [20433 rows x 8 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2121     -119.70     36.75                11.0       3626.0           779.0
# 6709     -118.15     34.14                52.0        403.0           117.0
# 18230    -122.09     37.40                17.0        748.0           184.0
# 12642    -121.46     38.54                39.0       1453.0           324.0
# 4419     -118.26     34.08                45.0       2225.0           827.0
# ...          ...       ...                 ...          ...             ...
# 6305     -117.88     34.00                32.0        265.0            51.0
# 4651     -118.32     34.06                43.0       2808.0           584.0
# 8228     -118.19     33.77                35.0       1574.0           603.0
# 18009    -121.97     37.29                29.0       2721.0           682.0
# 5583     -118.30     33.82                26.0       2080.0           560.0
#
#        population  households  median_income  median_house_value
# 2121       1819.0       731.0         2.4956             87500.0
# 6709        361.0       105.0         1.6250            187500.0
# 18230       412.0       180.0         3.4375            290600.0
# 12642       843.0       281.0         1.7692             63900.0
# 4419       2699.0       792.0         1.9209            179200.0
# ...           ...         ...            ...                 ...
# 6305        170.0        50.0         3.9375            187500.0
# 4651       1654.0       569.0         4.1250            436800.0
# 8228        820.0       514.0         1.2321            137500.0
# 18009      1602.0       646.0         3.3370            265300.0
# 5583       2096.0       506.0         2.8106            184400.0
#
# [16346 rows x 9 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925301           -0.103704     0.036574
# latitude            -0.925301  1.000000            0.007028    -0.027760
# housing_median_age  -0.103704  0.007028            1.000000    -0.365766
# total_rooms          0.036574 -0.027760           -0.365766     1.000000
# total_bedrooms       0.061761 -0.059230           -0.320101     0.926809
# population           0.093409 -0.102661           -0.299275     0.857164
# households           0.048482 -0.064111           -0.301737     0.915576
# median_income       -0.017396 -0.076519           -0.124368     0.203757
# median_house_value  -0.045278 -0.143232            0.104548     0.139719
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.061761    0.093409    0.048482      -0.017396
# latitude                 -0.059230   -0.102661   -0.064111      -0.076519
# housing_median_age       -0.320101   -0.299275   -0.301737      -0.124368
# total_rooms               0.926809    0.857164    0.915576       0.203757
# total_bedrooms            1.000000    0.883440    0.979884      -0.010177
# population                0.883440    1.000000    0.912130       0.000218
# households                0.979884    0.912130    1.000000       0.011827
# median_income            -0.010177    0.000218    0.011827       1.000000
# median_house_value        0.051877   -0.026466    0.067601       0.687301
#
#                     median_house_value
# longitude                    -0.045278
# latitude                     -0.143232
# housing_median_age            0.104548
# total_rooms                   0.139719
# total_bedrooms                0.051877
# population                   -0.026466
# households                    0.067601
# median_income                 0.687301
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot= True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data["total_rooms"] = np.log(train_data["total_rooms"] + 1)
train_data["total_bedrooms"] = np.log(train_data["total_bedrooms"] + 1)
train_data["population"] = np.log(train_data["population"] + 1)
train_data["households"] = np.log(train_data["households"] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y = "longitude", data=train_data, hue = "median_house_value", palette= "coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"] = train_data["total_bedrooms"]/train_data["total_rooms"]
train_data["household_rooms"] = train_data["total_rooms"]/train_data["households"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot= True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train,y_train = train_data.drop(["median_house_value"],axis=1), train_data["median_house_value"]
X_train_s = scaler.fit_transform(X_train)
reg = LinearRegression()
reg.fit(X_train_s,y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)
test_data["total_rooms"] = np.log(test_data["total_rooms"] + 1)
test_data["total_bedrooms"] = np.log(test_data["total_bedrooms"] + 1)
test_data["population"] = np.log(test_data["population"] + 1)
test_data["households"] = np.log(test_data["households"] + 1)
test_data["bedroom_ratio"] = test_data["total_bedrooms"]/test_data["total_rooms"]
test_data["household_rooms"] = test_data["total_rooms"]/test_data["households"]
X_test,y_test = test_data.drop(["median_house_value"],axis=1), test_data["median_house_value"]

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5759     -118.29     34.17                17.0     8.256607        6.972606
# 13251    -117.69     34.11                16.0     7.794823        6.259581
# 10962    -117.88     33.78                26.0     7.503290        6.045005
# 9704     -121.64     36.66                24.0     8.063063        6.228511
# 18502    -121.37     37.06                25.0     6.163315        4.532599
# ...          ...       ...                 ...          ...             ...
# 12788    -121.44     38.62                37.0     7.382746        5.955837
# 13035    -121.17     38.71                15.0     8.034307        6.324359
# 5540     -118.43     33.96                16.0     9.608579        8.290293
# 5111     -118.31     33.96                48.0     7.608871        5.877736
# 17050    -122.28     37.47                44.0     6.761573        4.744932
#
#        population  households  median_income  median_house_value  \
# 5759     8.002025    6.901737         2.3482            255400.0
# 13251    6.678342    6.198479         2.6929            119300.0
# 10962    7.119636    5.840642         3.5972            187500.0
# 9704     7.290975    6.284134         5.2285            248100.0
# 18502    5.707110    4.653960         3.8062            340900.0
# ...           ...         ...            ...                 ...
# 12788    6.880384    5.872118         1.9107             64700.0
# 13035    6.947937    6.333280         2.5183            293300.0
# 5540     8.743691    8.187577         5.1064            283200.0
# 5111     6.928538    5.826000         4.0625            138700.0
# 17050    5.641907    4.605170         6.8879            500001.0
#
#        bedroom_ratio  household_rooms
# 5759        0.844488         1.196309
# 13251       0.803043         1.257538
# 10962       0.805647         1.284669
# 9704        0.772475         1.283083
# 18502       0.735416         1.324316
# ...              ...              ...
# 12788       0.806724         1.257254
# 13035       0.787169         1.268586
# 5540        0.862801         1.173556
# 5111        0.772485         1.306020
# 17050       0.701750         1.468257
#
# [4087 rows x 11 columns]

# %%
X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test_s,y_test)
# Out:
# 0.669553457083862
